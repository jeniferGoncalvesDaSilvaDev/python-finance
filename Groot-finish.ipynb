# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/python-finance/blob/main/Groot-finish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#desafio atravessar o rio 
#items: pai, mae, 2 filhos, duas filhas, policial, prisioneira 
margemA = ['pai', 'mae', 'filho1', 'filho2', 'filha1', 'filha2', 'policial', 'prisioneiro']
margemB = []
jangada = []
#a condiçao deve-se retonar true ou false
"""
Cenário: oito pessoas estão em uma margem de um rio e precisam
atravessá-lo. O único meio de transporte para a travessia é uma jangada. As
pessoas que precisam atravessar o rio são: pai, mãe, dois filhos, duas filhas,
um policial e uma prisioneira.
Porém, para a travessia, algumas regras são obrigatórias e precisam ser
seguidas:
1. A jangada só pode carregar duas pessoas por vez;
2. Somente o pai, a mãe e o policial sabem manobrar a jangada;
3. Os filhos não podem ficar com a mãe na ausência do pai em nenhuma
das margens do rio;
4. Os filhos não podem ser transportados pela mãe;
5. As filhas não podem ficar com o pai na ausência da mãe em nenhuma das
margens do rio;
6. As filhas não podem ser transportadas pelo pai;
7. A prisioneira não pode
"""
#verificar o numero de itens permitido na jangada
#pai
if len(jangada)> 2:
   print('false')
else:
   jangada.append(margemA[0])
   jangada.append(margemA[2])
   if 'pai'and 'filho1' in jangada:
    print('true')
    margemB.append(margemA[2])
    print(margemB)
   else:
    print('false')
if len(jangada) >2:
  print('false')
else:
  jangada.append(margemA[0])
  jangada.append(margemA[3])
  if 'pai' and 'filho2' in jangada:
    print('true')
    margemB.append(margemA[3])
    print(margemB)
  else:
    print('false')
jangada.remove('pai')
#print(jangada)
jangada.remove('filho1')
#print(jangada)
jangada.remove('filho2')
#print(jangada)

#mae
jangada.append(margemA[1])
print(jangada)
if len(jangada)>2:
  print('false')
else:
  margemB.append(jangada[0])
  print('true')
  print(margemB)
if 'pai' in jangada:
  jangada.remove('pai')
  print('removido')
  print(jangada)
if len(jangada)>2:
  print('false')
else:
  jangada.append(margemA[4])
  print('true')
  print(jangada)
  if 'pai' in margemB:
    margemB.remove('pai')
    print(margemB)
  if 'filho1' and 'filho2' in margemB:
    margemB.append(jangada[1])
    print('true')
    print(margemB)
if 'filha1' in jangada:
  jangada.remove('filha1')
  print('removido')
if len(jangada)>2:
  print('false')
else:
  jangada.append(margemA[5])
  print('true')
  print(jangada)
  if 'filho1' and 'filho2' and 'filha1':
    margemB.append(jangada[1])
    print('true')
    print(margemB)

if 'filha2' in jangada:
  jangada.remove('filha2')
  print('removido')
  print(jangada)


if 'mae' in jangada:
  jangada.remove('mae')
  print('removido')
  print(jangada)




margemA.remove('filho1')
margemA.remove('filho2')
margemA.remove('filha1')
margemA.remove('filha2')
print(margemA)
#policial e prisioneira
if len(jangada)>2:
  print('false')
else:
  print('true')
  jangada.append(margemA[2])
  jangada.append(margemA[3])
  print(jangada)
  if 'policial' and 'prisioneiro':
    margemB.append(jangada[0])
    margemB.append(jangada[1])
    print(margemB)
    if 'policial' and 'prisioneiro':
      jangada.remove('policial')
      jangada.remove('prisioneiro')
      print('removido')
      print(jangada)
margemA.remove('policial')
margemA.remove('prisioneiro')
print(margemA)
if len(jangada)>2:
  print('false')
else:
  jangada.append(margemA[0])
  jangada.append(margemA[1])
  if 'pai' and 'mae' not in margemB:
    margemB.append(jangada[0])
    margemB.append(jangada[1])
    print(margemB)
  elif 'pai' and 'mae' in jangada:
    jangada.remove('pai')
    jangada.remove('mae')



margemA.remove('pai')
margemA.remove('mae')
print(margemA)
print('concluido')
print(margemB)
# Out:
# true
# ['filho1']
# true
# ['filho1', 'filho2']
# ['pai', 'mae']
# true
# ['filho1', 'filho2', 'pai']
# removido
# ['mae']
# true
# ['mae', 'filha1']
# ['filho1', 'filho2']
# true
# ['filho1', 'filho2', 'filha1']
# removido
# true
# ['mae', 'filha2']
# true
# ['filho1', 'filho2', 'filha1', 'filha2']
# removido
# ['mae']
# removido
# []
# ['pai', 'mae', 'policial', 'prisioneiro']
# true
# ['policial', 'prisioneiro']
# ['filho1', 'filho2', 'filha1', 'filha2', 'policial', 'prisioneiro']
# removido
# []
# ['pai', 'mae']
# ['filho1', 'filho2', 'filha1', 'filha2', 'policial', 'prisioneiro', 'pai', 'mae']
# []
# concluido
# ['filho1', 'filho2', 'filha1', 'filha2', 'policial', 'prisioneiro', 'pai', 'mae']
